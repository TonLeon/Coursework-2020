# %%
import pymystem3

# %%
import re

# %%
# !pip install transliterate
# Out:
# Collecting transliterate
#   Using cached https://files.pythonhosted.org/packages/a1/6e/9a9d597dbdd6d0172427c8cc07c35736471e631060df9e59eeb87687f817/transliterate-1.10.2-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.1.0 in c:\users\elisaveta\anaconda3\lib\site-packages (from transliterate) (1.12.0)
# Installing collected packages: transliterate
# Successfully installed transliterate-1.10.2

# %%
import transliterate

# %%
#эта часть кода открывает твой текст, лемматизирует его по определенному принципу (здесь принцип -c - он сохраняет оригинал и при этом рядом пишет лемму)
#и сохраняет его в новом файле, который стоит заранее создать. 
#вначале надо писать путь к программе mystem, потом путь к редактируемому тексту, потом путь к пустому файлу, куда все сохранится
# !C:\Users\Elisaveta\MyStem\mystem.exe C:\Users\Elisaveta\Desktop\Coursework\clean_2_level.txt C:\Users\Elisaveta\MyStem\test1.txt -c

# %%
f = open(r'C:\Users\Elisaveta\Desktop\Coursework\Otryvok_iz_dnevnika.txt', encoding = "UTF-8") #открываем кусок дневника
text = f.read()
f.close()
dnevnik = text.split() #сплитим кусок по пробелам и видим слово и его лемму

# %%
dnevnik
# Out:
# ['В{в}',
#  '"Днях{день}"',
#  'напечатан{напечатать}',
#  'рассказ{рассказ}',
#  'Г{г}.',
#  'Н{н}.',
#  '[Кузнецовой{кузнецова}.',
#  '--',
#  'М{м}.',
#  'Г{г}.].',
#  'Статья{статья}',
#  'Макеева{макеев|макеева}',
#  'о{о}',
#  '"Совр{совр?|совра?|совры?|совро?}.',
#  'Зап{зап?|запа?}."',
#  'Восхищается{восхищаться}',
#  '"Божьим{божий}',
#  'Древом{древо}"1,',
#  'но{но}',
#  'говорит{говорить},',
#  'что{что}',
#  'эта{этот|эта}',
#  'жизнь{жизнь}',
#  'канула{кануть}',
#  'в{в}',
#  'вечность{вечность}.',
#  'Ян{ян|яна}',
#  'сказал{сказать}:']

# %%
f = open(r"C:\Users\Elisaveta\Desktop\Coursework\1_clear_surnames_russian.txt", "r", encoding = "UTF-8") #открываем файл со списком
                                                                                                         #русских фамилий без инициалов
list1 = f.readlines()
f.close()
list_of_surnames = []
for w in list1:
    w = w.lower() #приводим фамилии к нижнему регистру
    if w:
        list_of_surnames.append(w.strip()) #добавляем это все в новый список
        
list_of_surnames_english = [] #создаем пустой список для английского транслита
for n in list_of_surnames: #обращаемся к списку с фамилиями на русском
    if n:
        name = transliterate.translit(n, reversed=True) #транслитерируем русскую фамилию
        list_of_surnames_english.append(name) #добавляем в пустой список, где должен быть транлит
        

dict_surnames = dict(zip(list_of_surnames, list_of_surnames_english)) #соединяем два списка - с фамилиями на рус и англ, получая таким образом словарь

#with open(r".\Dictionary of surnames.txt", "w") as fw:
  #  for word in d:
  #      fw.write("{} \t {}\n". format(word, d[word]))

# %%
dict_surnames
# Out:
# {'авилов': 'avilov',
#  'авилова': 'avilova',
#  'авиловы': 'avilovy',
#  'авксентьев': "avksent'ev",
#  'авксентьева': "avksent'eva",
#  'ага': 'aga',
#  'агралл': 'agrall',
#  'адамович': 'adamovich',
#  'азеф': 'azef',
#  'аитов': 'aitov',
#  'аитова': 'aitova',
#  'айхенвальд': "ajhenval'd",
#  'алданов': 'aldanov',
#  'алдановы': 'aldanovy',
#  'алексинский': 'aleksinskij',
#  'алексинская': 'aleksinskaja',
#  'алексинские': 'aleksinskie',
#  'альтшулер': "al'tshuler",
#  'аминад': 'aminad',
#  'дон аминадо': 'don aminado',
#  'амфитеатров': 'amfiteatrov',
#  'андреев': 'andreev',
#  'апухтин': 'apuhtin',
#  'аргутинский': 'argutinskij',
#  'аргутинские': 'argutinskie',
#  'арсеньев': "arsen'ev",
#  'афонский': 'afonskij',
#  'бакст': 'bakst',
#  'балавинский': 'balavinskij',
#  'балахович': 'balahovich',
#  'бальмонт': "bal'mont",
#  'бальмонты': "bal'monty",
#  'баратов': 'baratov',
#  'барятинский': 'barjatinskij',
#  'беек': 'beek',
#  'белинский': 'belinskij',
#  'белич': 'belich',
#  'белобородое': 'beloborodoe',
#  'белый': 'belyj',
#  'бенеш': 'benesh',
#  'берберова': 'berberova',
#  'бердяев': 'berdjaev',
#  'бернацкий': 'bernatskij',
#  'бернацкие': 'bernatskie',
#  'бетховен': 'bethoven',
#  'билибин': 'bilibin',
#  'блок': 'blok',
#  'блох': 'bloh',
#  'блохи': 'blohi',
#  'борис влад.': 'boris vlad.',
#  'боссар': 'bossar',
#  'брежнев': 'brezhnev',
#  'брежневы': 'brezhnevy',
#  'брешко-брешковский': 'breshko-breshkovskij',
#  'брюсов': 'brjusov',
#  'будберг': 'budberg',
#  'буковецкий': 'bukovetskij',
#  'бунаков': 'bunakov',
#  'бунин': 'bunin',
#  'бунина': 'bunina',
#  'бунины': 'buniny',
#  'бурд': 'burd',
#  'бурцев': 'burtsev',
#  'бухарин': 'buharin',
#  'валери': 'valeri',
#  'васильев': "vasil'ev",
#  'вахрушевы': 'vahrushevy',
#  'вересаев': 'veresaev',
#  'вертинский': 'vertinskij',
#  'верхарн': 'verharn',
#  'веселовский': 'veselovskij',
#  'винтерфельд': "vinterfel'd",
#  'вишневский': 'vishnevskij',
#  'вишняк': 'vishnjak',
#  'володарский': 'volodarskij',
#  'волынский': 'volynskij',
#  'врангель': "vrangel'",
#  'врубель': "vrubel'",
#  'вульф': "vul'f",
#  'вырубов': 'vyrubov',
#  'высоцкая': 'vysotskaja',
#  'вышеславцев': 'vysheslavtsev',
#  'вышеславцева': 'vysheslavtseva',
#  'гааз': 'gaaz',
#  'габрилович': 'gabrilovich',
#  'гавронская': 'gavronskaja',
#  'гавронский': 'gavronskij',
#  'гальперн': "gal'pern",
#  'гамсун': 'gamsun',
#  'гербер': 'gerber',
#  'гершензон': 'gershenzon',
#  'гессен': 'gessen',
#  'гете': 'gete',
#  'гиппиус': 'gippius',
#  'гирс': 'girs',
#  'гитлер': 'gitler',
#  'глазунов': 'glazunov',
#  'гликберг': 'glikberg',
#  'голобородько': "goloborod'ko",
#  'голштейн': 'golshtejn',
#  'гольдштейн': "gol'dshtejn",
#  'гольцев': "gol'tsev",
#  'гончарова': 'goncharova',
#  'гораций': 'goratsij',
#  'горький': "gor'kij",
#  'горькие': "gor'kie",
#  'гофман': 'gofman',
#  'гребенщиков': 'grebenschikov',
#  'гребенщиковы': 'grebenschikovy',
#  'григ': 'grig',
#  'григорьев': "grigor'ev",
#  'гримм': 'grimm',
#  'гукасов': 'gukasov',
#  'гуль': "gul'",
#  'гусаков': 'gusakov',
#  'густав': 'gustav',
#  'гутман': 'gutman',
#  'гучков': 'guchkov',
#  'даль': "dal'",
#  'дали': 'dali',
#  'данте': 'dante',
#  'дейч': 'dejch',
#  'демидов': 'demidov',
#  'демидова': 'demidova',
#  'деникин': 'denikin',
#  'денисов': 'denisov',
#  'денисова': 'denisova',
#  'джемс': 'dzhems',
#  'дзержинский': 'dzerzhinskij',
#  'дионео': 'dioneo',
#  'донзель морис': "donzel' moris",
#  'достоевский': 'dostoevskij',
#  'дроздов': 'drozdov',
#  'дурново': 'durnovo',
#  'дягилев': 'djagilev',
#  'дьякова': "d'jakova",
#  'евлогий': 'evlogij',
#  'елпатьевский': "elpat'evskij",
#  'ельяшевич': "el'jashevich",
#  'еремеева': 'eremeeva',
#  'есенин': 'esenin',
#  'жид': 'zhid',
#  'жозеф': 'zhozef',
#  'зайцев': 'zajtsev',
#  'борис': 'boris',
#  'боря': 'borja',
#  'зайцева': 'zajtseva',
#  'верочка': 'verochka',
#  'зайцевы': 'zajtsevy',
#  'зайчики': 'zajchiki',
#  'замятин': 'zamjatin',
#  'зенинов': 'zeninov',
#  'зернов': 'zernov',
#  'зилотти': 'zilotti',
#  'злобин': 'zlobin',
#  'володя': 'volodja',
#  'зноские': 'znoskie',
#  'зуров': 'zurov',
#  'леня': 'lenja',
#  'скабарь': "skabar'",
#  'питомец': 'pitomets',
#  'лось': "los'",
#  'ибаньес бласко': "iban'es blasko",
#  'иванов': 'ivanov',
#  'игнатьев': "ignat'ev",
#  'иловайская': 'ilovajskaja',
#  'иловайский': 'ilovajskij',
#  'иловайские': 'ilovajskie',
#  'ильин': "il'in",
#  'ильины': "il'iny",
#  'инбер': 'inber',
#  'иоанн грозный': 'ioann groznyj',
#  'иоанн сан-францисский': 'ioann san-frantsisskij',
#  'каган-семенов': 'kagan-semenov',
#  'кал грен': 'kal gren',
#  'каллаш': 'kallash',
#  'курдюмов': 'kurdjumov',
#  'каляев': 'kaljaev',
#  'капитан': 'kapitan',
#  'рощин': 'roschin',
#  'карабчевский': 'karabchevskij',
#  'карлфельд': "karlfel'd",
#  'карташев': 'kartashev',
#  'карташевы': 'kartashevy',
#  'карсавина': 'karsavina',
#  'катаев': 'kataev',
#  'качалов': 'kachalov',
#  'кедрин': 'kedrin',
#  'кедровы': 'kedrovy',
#  'керенский': 'kerenskij',
#  'кессель': "kessel'",
#  'кизеветтер': 'kizevetter',
#  'кишкин': 'kishkin',
#  'клодиа': 'klodia',
#  'ключевский': 'kljuchevskij',
#  'книппер': 'knipper',
#  'ковалевский': 'kovalevskij',
#  'койранский': 'kojranskij',
#  'койранские': 'kojranskie',
#  'колчак': 'kolchak',
#  'комиссаржевская': 'komissarzhevskaja',
#  'конюс': 'konjus',
#  'рахманинова': 'rahmaninova',
#  'корнилов': 'kornilov',
#  'короленко': 'korolenko',
#  'крандиевский': 'krandievskij',
#  'кречетов': 'krechetov',
#  'кречетовы': 'krechetovy',
#  'кривошеий': 'krivosheij',
#  'кривошеины': 'krivosheiny',
#  'кронштадский о. иоанн': 'kronshtadskij o. ioann',
#  'крымов': 'krymov',
#  'кугушева': 'kugusheva',
#  'кугушевы': 'kugushevy',
#  'кузнецова': 'kuznetsova',
#  'кузьмин-караваев д.': "kuz'min-karavaev d.",
#  'кульман н. к.': "kul'man n. k.",
#  'кульман н. и.': "kul'man n. i.",
#  'кульманы': "kul'many",
#  'кун бэлла': 'kun bella',
#  'кулябко-карецкий н. и.': 'kuljabko-karetskij n. i.',
#  'куприн а. и.': 'kuprin a. i.',
#  'куприна е. м.': 'kuprina e. m.',
#  'лизи': 'lizi',
#  'куприны': 'kupriny',
#  'курдюмов см. каллаш': 'kurdjumov sm. kallash',
#  'кусевицкий с. а.': 'kusevitskij s. a.',
#  'кусиков': 'kusikov',
#  'кускова е. д.': 'kuskova e. d.',
#  'кустодиев б. м.': 'kustodiev b. m.',
#  'кутепов а. п.': 'kutepov a. p.',
#  'кянжунцевы': 'kjanzhuntsevy',
#  'лавров п. л.': 'lavrov p. l.',
#  'ладыженский в. н.': 'ladyzhenskij v. n.',
#  'лазаревский б. а.': 'lazarevskij b. a.',
#  'ландау гр.': 'landau gr.',
#  'ландау м. а.': 'landau m. a.',
#  'ландау т. м.': 'landau t. m.',
#  'лаоцзы': 'laotszy',
#  'лапинская': 'lapinskaja',
#  'ларионов м. ф.': 'larionov m. f.',
#  'левина м.': 'levina m.',
#  'левины': 'leviny',
#  'ленин в. и.': 'lenin v. i.',
#  'леонтьев к.': "leont'ev k.",
#  'лермонтов м. ю.': 'lermontov m. ju.',
#  'лист ф.': 'list f.',
#  'литовцев, см. поляков-литовцев с. л.': 'litovtsev, sm. poljakov-litovtsev s. l.',
#  'лифарь с. м.': "lifar' s. m.",
#  'лихошерстов': 'lihosherstov',
#  'ллойд джордж д.': 'llojd dzhordzh d.',
#  'лоло': 'lolo',
#  'мунштейн в. н.': 'munshtejn v. n.',
#  'лопатин вл. м.': 'lopatin vl. m.',
#  'лопатин л. м.': 'lopatin l. m.',
#  'лопатина ек. м.': 'lopatina ek. m.',
#  'лопатэн': 'lopaten',
#  'лохвицкий': 'lohvitskij',
#  'лужские': 'luzhskie',
#  'луначарский а. в.': 'lunacharskij a. v.',
#  'лурье с. в.': "lur'e s. v.",
#  'львов г. е.': "l'vov g. e.",
#  'львов лоллий и.': "l'vov lollij i.",
#  'любимов': 'ljubimov',
#  'лютер а.': 'ljuter a.',
#  'ляцкий е. а.': 'ljatskij e. a.',
#  'маан': 'maan',
#  'мак': 'mak',
#  'магеровский л. ф.': 'magerovskij l. f.',
#  'макеев': 'makeev',
#  'маклаков в. а.': 'maklakov v. a.',
#  'маклакова м.': 'maklakova m.',
#  'маклаковы': 'maklakovy',
#  'маклаков ю. н.': 'maklakov ju. n.',
#  'маковский с. к.': 'makovskij s. k.',
#  'малиновская': 'malinovskaja',
#  'малиновский': 'malinovskij',
#  'малявин ф. а.': 'maljavin f. a.',
#  'мамонтов савва': 'mamontov savva',
#  'манн томас': 'mann tomas',
#  'мансфильд кат.': "mansfil'd kat.",
#  'манухин и. и.': 'manuhin i. i.',
#  'манухина т. и.': 'manuhina t. i.',
#  'манухины': 'manuhiny',
#  'маркс карл': 'marks karl',
#  'маршак а. о.': 'marshak a. o.',
#  'маяковский в.': 'majakovskij v.',
#  'медичи ек.': 'medichi ek.',
#  'мейнгард': 'mejngard',
#  'мельгунов сп.': "mel'gunov sp.",
#  'мельников-печерский п. и.': "mel'nikov-pecherskij p. i.",
#  'менье': "men'e",
#  'мережковский д. с.': 'merezhkovskij d. s.',
#  'мережковская зин. н.': 'merezhkovskaja zin. n.',
#  'мережковские': 'merezhkovskie',
#  'микоян а.': 'mikojan a.',
#  'милица ник.': 'militsa nik.',
#  'миллер е. к.': 'miller e. k.',
#  'милль пьер': "mill' p'er",
#  'милюков п. н.': 'miljukov p. n.',
#  'минский h. m.': 'minskij h. m.',
#  'виленкин': 'vilenkin',
#  'минские': 'minskie',
#  'миронов н. д.': 'mironov n. d.',
#  'мироновы': 'mironovy',
#  'мирский д. п.': 'mirskij d. p.',
#  'святополк-мирский': 'svjatopolk-mirskij',
#  'михайлов': 'mihajlov',
#  'михайлов п. а.': 'mihajlov p. a.',
#  'михайловы': 'mihajlovy',
#  'могилянский': 'mogiljanskij',
#  'моисеенко е. и.': 'moiseenko e. i.',
#  'могилевский': 'mogilevskij',
#  'мольер': "mol'er",
#  'мопассан': 'mopassan',
#  'москвин и. м.': 'moskvin i. m.',
#  'мочульский к. в.': "mochul'skij k. v.",
#  'муллен камилл де': 'mullen kamill de',
#  'мунейхин мисюрь': "munejhin misjur'",
#  'муромцев вс. н.': 'muromtsev vs. n.',
#  'сева': 'seva',
#  'муромцев дм. н.': 'muromtsev dm. n.',
#  'митя': 'mitja',
#  'муромцев н.': 'muromtsev n.',
#  'муромцев п. н.': 'muromtsev p. n.',
#  'павлик': 'pavlik',
#  'муромцева л. ф.': 'muromtseva l. f.',
#  'муссолини': 'mussolini',
#  'мустангет': 'mustanget',
#  'набоков в. д.': 'nabokov v. d.',
#  'наполеон': 'napoleon',
#  'нарышкины': 'naryshkiny',
#  'неклюдов а. в.': 'nekljudov a. v.',
#  'неклюдова': 'nekljudova',
#  'неклюдовы': 'nekljudovy',
#  'немирович-данченко в. и.': 'nemirovich-danchenko v. i.',
#  'нижинская': 'nizhinskaja',
#  'нилус п. а.': 'nilus p. a.',
#  'петр': 'petr',
#  'нилус б. с.': 'nilus b. s.',
#  'нилусы': 'nilusy',
#  'нобель альфред': "nobel' al'fred",
#  'нобель г. л.': "nobel' g. l.",
#  'нобель марта л.': "nobel' marta l.",
#  'нобель э. л.': "nobel' e. l.",
#  'нобели': 'nobeli',
#  'новгородцев п. и.': 'novgorodtsev p. i.',
#  'новосильцев': "novosil'tsev",
#  'нольде б. э.': "nol'de b. e.",
#  'нувель в. ф.': "nuvel' v. f.",
#  'овсянико-куликовский д. н.': 'ovsjaniko-kulikovskij d. n.',
#  'одоевцева ирина': 'odoevtseva irina',
#  'олейников': 'olejnikov',
#  'олейниковы': 'olejnikovy',
#  'ольденбургский а. п.': "ol'denburgskij a. p.",
#  'орлов-давыдов': 'orlov-davydov',
#  'осоргин м. а.': 'osorgin m. a.',
#  'осоргина': 'osorgina',
#  'рери': 'reri',
#  'осоргины': 'osorginy',
#  'оцуп н. а.': 'otsup n. a.',
#  'павловичи': 'pavlovichi',
#  'палеолог': 'paleolog',
#  'петр николаевич': 'petr nikolaevich',
#  'петрарка': 'petrarka',
#  'петровская h. и.': 'petrovskaja h. i.',
#  'соколова-кречетова': 'sokolova-krechetova',
#  'пешков а. м.': 'peshkov a. m.',
#  'пешков максим': 'peshkov maksim',
#  'пешкова е. п.': 'peshkova e. p.',
#  'пикассо пабло': 'pikasso pablo',
#  'пилкины': 'pilkiny',
#  'пилсудский ю.': 'pilsudskij ju.',
#  'писаревские': 'pisarevskie',
#  'плевако ф. н.': 'plevako f. n.',
#  'плевицкая н. в.': 'plevitskaja n. v.',
#  'плеханов г. в.': 'plehanov g. v.',
#  'плещеев': 'plescheev',
#  'плотин': 'plotin',
#  'полнер т. и.': 'polner t. i.',
#  'полонский я. б.': 'polonskij ja. b.',
#  'полонские': 'polonskie',
#  'поляков а. а.': 'poljakov a. a.',
#  'поляков-литовцев с. л.': 'poljakov-litovtsev s. l.',
#  'потресов с. в': 'potresov s. v',
#  'прево марсель': "prevo marsel'",
#  'прокопович': 'prokopovich',
#  'прокофьев с. с.': "prokof'ev s. s.",
#  'пруст м.': 'prust m.',
#  'пуанкарэ р.': 'puankare r.',
#  'пуарэ': 'puare',
#  'пэти е. ю.': 'peti e. ju.',
#  'раковский': 'rakovskij',
#  'рахманинов с. в.': 'rahmaninov s. v.',
#  'конюс т. с.': 'konjus t. s.',
#  'рахманиновы': 'rahmaninovy',
#  'рачковский': 'rachkovskij',
#  'ремизов а. м.': 'remizov a. m.',
#  'репин илья': "repin il'ja",
#  'рильке райнер м.': "ril'ke rajner m.",
#  'роговский': 'rogovskij',
#  'роджерс': 'rodzhers',
#  'родэн р. ф. о.': 'roden r. f. o.',
#  'розанов в. в.': 'rozanov v. v.',
#  'розенберг к.': 'rozenberg k.',
#  'розенталь л. м.': "rozental' l. m.",
#  'роллан ромэн': 'rollan romen',
#  'ролль': "roll'",
#  'романовы': 'romanovy',
#  'ростовцев м. и.': 'rostovtsev m. i.',
#  'ростовцевы': 'rostovtsevy',
#  'рощин н.': 'roschin n.',
#  'рощина-инсарова е.': 'roschina-insarova e.',
#  'руднев в. в.': 'rudnev v. v.',
#  'рудневы': 'rudnevy',
#  'русов': 'rusov',
#  'рябушинская м. д.': 'rjabushinskaja m. d.',
#  'савельев а.': "savel'ev a.",
#  'савинков б. в.': 'savinkov b. v.',
#  'савинкова е. и.': 'savinkova e. i.',
#  'савинковы': 'savinkovy',
#  'сазонов и.': 'sazonov i.',
#  'сальери а.': "sal'eri a.",
#  'самойловы': 'samojlovy',
#  'серов с. м.': 'serov s. m.',
#  'сирин': 'sirin',
#  'набокова в.в.': 'nabokova v.v.',
#  'скирмунт с. а.': 'skirmunt s. a.',
#  'скобцова е. ю.': 'skobtsova e. ju.',
#  'скоропадский п. п.': 'skoropadskij p. p.',
#  'соколов с. а.': 'sokolov s. a.',
#  'солдатский': 'soldatskij',
#  'соллогуб н. б.': 'sollogub n. b.',
#  'соллогубы': 'solloguby',
#  'соловьев с. м.': "solov'ev s. m.",
#  'соловьев влад.': "solov'ev vlad.",
#  'соломон': 'solomon',
#  'сорин с.': 'sorin s.',
#  'сосновский': 'sosnovskij',
#  'спасский о. георгий': 'spasskij o. georgij',
#  'спесивцева': 'spesivtseva',
#  'спирович': 'spirovich',
#  'спировичи': 'spirovichi',
#  'сталин': 'stalin',
#  'сталь м-ме де': "stal' m-me de",
#  'станиславский к. с.': 'stanislavskij k. s.',
#  'стахович г. е.': 'stahovich g. e.',
#  'стеллецкий д. с.': 'stelletskij d. s.',
#  'стендаль': "stendal'",
#  'степун марг. а.': 'stepun marg. a.',
#  'степун ф. а.': 'stepun f. a.',
#  'степун нат.': 'stepun nat.',
#  'степуны': 'stepuny',
#  'стравинский игорь': "stravinskij igor'",
#  'струве а. п.': 'struve a. p.',
#  'струве г. п.': 'struve g. p.',
#  'струве п. б.': 'struve p. b.',
#  'судейкин с.': 'sudejkin s.',
#  'сургучев и. д.': 'surguchev i. d.',
#  'тагор рабиндранат': 'tagor rabindranat',
#  'тарновский': 'tarnovskij',
#  'татаринов': 'tatarinov',
#  'телешов а. н.': 'teleshov a. n.',
#  'телешов н. д.': 'teleshov n. d.',
#  'телешова ел. а.': 'teleshova el. a.',
#  'телешовы': 'teleshovy',
#  'темирязев': 'temirjazev',
#  'теодорик': 'teodorik',
#  'тикстон п. а.': 'tikston p. a.',
#  'тихон патриарх': 'tihon patriarh',
#  'токарский': 'tokarskij',
#  'толстой а. к.': 'tolstoj a. k.',
#  'толстой а. н.': 'tolstoj a. n.',
#  'толстая н.': 'tolstaja n.',
#  'наташа': 'natasha',
#  'толстые': 'tolstye',
#  'толстые ника': 'tolstye nika',
#  'фефа': 'fefa',
#  'марьяна': "mar'jana",
#  'толстая а. л.': 'tolstaja a. l.',
#  'толстой лев': 'tolstoj lev',
#  'толстая с. а.': 'tolstaja s. a.',
#  'топорков': 'toporkov',
#  'третьяковы': "tret'jakovy",
#  'троцкий и.': 'trotskij i.',
#  'троцкий лев': 'trotskij lev',
#  'тыркова-вильямс а. в.': "tyrkova-vil'jams a. v.",
#  'тэффи н. а.': 'teffi n. a.',
#  'лохвицкая': 'lohvitskaja',
#  'ундсет зигрид': 'undset zigrid',
#  'унковский': 'unkovskij',
#  'урицкий м.': 'uritskij m.',
#  'уэльс герберт': "uel's gerbert",
#  'фарер клод': 'farer klod',
#  'фареры': 'farery',
#  'федин к.': 'fedin k.',
#  'федоров а. м.': 'fedorov a. m.',
#  'федоров н.': 'fedorov n.',
#  'федотов г. п.': 'fedotov g. p.',
#  'филоненко m. m.': 'filonenko m. m.',
#  'философов д. в.': 'filosofov d. v.',
#  'флобер гюстав': 'flober gjustav',
#  'фондаминский и. и.': 'fondaminskij i. i.',
#  'бунаков-фондаминский': 'bunakov-fondaminskij',
#  'илис': 'ilis',
#  'илюша': 'iljusha',
#  'фондаминская а. о.': 'fondaminskaja a. o.',
#  'фондаминские': 'fondaminskie',
#  'франс анатоль': "frans anatol'",
#  'франциск i': 'frantsisk i',
#  'фрейд зигмунд': 'frejd zigmund',
#  'харитоненко': 'haritonenko',
#  'ховен': 'hoven',
#  'ходасевич в. д.': 'hodasevich v. d.',
#  'ходасевичи': 'hodasevichi',
#  'хомяков а. с.': 'homjakov a. s.',
#  'цакни а. н.': 'tsakni a. n.',
#  'цетлин а. в.': 'tsetlin a. v.',
#  'цетлин м. о.': 'tsetlin m. o.',
#  'цетлина м. с.': 'tsetlina m. s.',
#  'цетлины': 'tsetliny',
#  'цетлин о. с.': 'tsetlin o. s.',
#  'цветаева марина': 'tsvetaeva marina',
#  'цвибак я.': 'tsvibak ja.',
#  'андрей седых': 'andrej sedyh',
#  'чайковский н. в.': 'chajkovskij n. v.',
#  'чайковская в. н.': 'chajkovskaja v. n.',
#  'чайковский м.': 'chajkovskij m.',
#  'чернов в. m.': 'chernov v. m.',
#  'черный саша': 'chernyj sasha',
#  'гликберг а. м.': 'glikberg a. m.',
#  'чехов а. п.': 'chehov a. p.',
#  'чехов и. п.': 'chehov i. p.',
#  'чехов мих.': 'chehov mih.',
#  'чехова м. п.': 'chehova m. p.',
#  'чириков е.': 'chirikov e.',
#  'шаляпин федор': 'shaljapin fedor',
#  'шаляпина м. в.': 'shaljapina m. v.',
#  'шаляпина стелла': 'shaljapina stella',
#  'шапен м-лле': 'shapen m-lle',
#  'шассен': 'shassen',
#  'шаховская з. а.': 'shahovskaja z. a.',
#  'шаховской д. а.': 'shahovskoj d. a.',
#  'ш-ие': 'sh-ie',
#  'шекспир': 'shekspir',
#  'шеллинг': 'shelling',
#  'шестов лев': 'shestov lev',
#  'шестовы': 'shestovy',
#  'шиман, д-р': 'shiman, d-r',
#  'шишкина-афанасьева': "shishkina-afanas'eva",
#  'шкловский и. в.': 'shklovskij i. v.',
#  'шлецер б. ф.': 'shletser b. f.',
#  'шмелев и. с.': 'shmelev i. s.',
#  'шмелева о. а.': 'shmeleva o. a.',
#  'шмелевы': 'shmelevy',
#  'шполянский а. п.': 'shpoljanskij a. p.',
#  'дон-аминадо': 'don-aminado',
#  'штерн': 'shtern',
#  'шульгин в. в.': "shul'gin v. v.",
#  'щеголев м.': 'schegolev m.',
#  'щепкина-куперник т. л.': 'schepkina-kupernik t. l.',
#  'щербатов': 'scherbatov',
#  'эмилия вас.': 'emilija vas.',
#  'эренбург илья': "erenburg il'ja",
#  'эристова': 'eristova',
#  'эртель а. и.': "ertel' a. i.",
#  'эррио э.': 'errio e.',
#  'юрьев': "jur'ev",
#  'юсупов ф.': 'jusupov f.',
#  'юшкевич п.': 'jushkevich p.',
#  'юшкевич с. с.': 'jushkevich s. s.',
#  'яблоновский а.': 'jablonovskij a.',
#  'яблоновский с. в.': 'jablonovskij s. v.',
#  'потресов': 'potresov',
#  'яблоновские': 'jablonovskie',
#  'якобсон е.': 'jakobson e.',
#  'якунчикова': 'jakunchikova'}

# %%
reg = "\{\S*\}" #это регулярка для того, что находится в {} скобках
for string in dnevnik: #работаем с переменной, в которой у нас список со словами и их леммами
    allregs = re.findall(reg, string) #находим в списке подстроки, которые подходят под регулярку
    if allregs: #если нашли такую подстроку, начинаем ее очищать от всякой грязи
        for word in allregs: 
            word = word.strip('{}')
            word = word.replace("|", " ")
            word = word.replace("?","")
            word = word.split()
            print(word) 
            
            #if word in dict_surnames: #очистив от знаков препинания и скобок, ищем эту подстроку в словаре
             #   print(word.replace(word,'<persName ref=#'+dict_surnames[word]+'#>'+word+'</persName>')) #если находит, пишет тэг
            #else:
             #   print(string) #если такого нет в словаре, пишет изначальную строку, т.е. слово и его лемму
# Out:
# ['в']
# ['день']
# ['напечатать']
# ['рассказ']
# ['г']
# ['н']
# ['кузнецова']
# ['м']
# ['г']
# ['статья']
# ['макеев', 'макеева']
# ['о']
# ['совр', 'совра', 'совры', 'совро']
# ['зап', 'запа']
# ['восхищаться']
# ['божий']
# ['древо']
# ['но']
# ['говорить']
# ['что']
# ['этот', 'эта']
# ['жизнь']
# ['кануть']
# ['в']
# ['вечность']
# ['ян', 'яна']
# ['сказать']
